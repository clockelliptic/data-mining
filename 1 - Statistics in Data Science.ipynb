# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Statistics-in-Data-Science,-A-Review" data-toc-modified-id="Statistics-in-Data-Science,-A-Review-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Statistics in Data Science, A Review</a></span><ul class="toc-item"><li><span><a href="#Statistics-in-Python" data-toc-modified-id="Statistics-in-Python-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Statistics in Python</a></span><ul class="toc-item"><li><span><a href="#Statistics-Packages-for-Python" data-toc-modified-id="Statistics-Packages-for-Python-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Statistics Packages for Python</a></span><ul class="toc-item"><li><span><a href="#Importing-the-packages" data-toc-modified-id="Importing-the-packages-1.1.1.1"><span class="toc-item-num">1.1.1.1&nbsp;&nbsp;</span>Importing the packages</a></span></li><li><span><a href="#Testing-the-packages" data-toc-modified-id="Testing-the-packages-1.1.1.2"><span class="toc-item-num">1.1.1.2&nbsp;&nbsp;</span>Testing the packages</a></span></li></ul></li></ul></li><li><span><a href="#Types-of-Statistics:-Descriptive-&amp;-Inferential" data-toc-modified-id="Types-of-Statistics:-Descriptive-&amp;-Inferential-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Types of Statistics: Descriptive &amp; Inferential</a></span><ul class="toc-item"><li><span><a href="#Descriptive-Statistics" data-toc-modified-id="Descriptive-Statistics-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Descriptive Statistics</a></span></li><li><span><a href="#Inferential-Statistics" data-toc-modified-id="Inferential-Statistics-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Inferential Statistics</a></span><ul class="toc-item"><li><span><a href="#A-Closer-look-at-Statistical-Inference" data-toc-modified-id="A-Closer-look-at-Statistical-Inference-1.2.2.1"><span class="toc-item-num">1.2.2.1&nbsp;&nbsp;</span>A Closer look at Statistical Inference</a></span></li></ul></li><li><span><a href="#Types-of-Data" data-toc-modified-id="Types-of-Data-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Types of Data</a></span></li><li><span><a href="#Graphing-and-Visualizing-Data:" data-toc-modified-id="Graphing-and-Visualizing-Data:-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Graphing and Visualizing Data:</a></span><ul class="toc-item"><li><span><a href="#Graphing-Qualitative-Data" data-toc-modified-id="Graphing-Qualitative-Data-1.2.4.1"><span class="toc-item-num">1.2.4.1&nbsp;&nbsp;</span>Graphing Qualitative Data</a></span></li><li><span><a href="#Graphing-Quantitative-Data" data-toc-modified-id="Graphing-Quantitative-Data-1.2.4.2"><span class="toc-item-num">1.2.4.2&nbsp;&nbsp;</span>Graphing Quantitative Data</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Statistics in Data Science, A Review

# %% [markdown]
# __Purpose:__ The purpose of this sction is to perform a brief but comprehensive review of the field of Statistics as applied in Data Science. We will cover the most important introductory topics of Statistics starting with the type of statistics, graphing and summarizing data, comparing sample vs. population, and concepts such as Central Limit Theorem, estimators, Law of Large Numbers, and then end with confidence intervals and hypothesis testing.
#
# __At the end of this section we will have reviewed how to do the following with Python:__
# > 1. Understand and define Statistics as well as differentiate between Decriptive and Inferential Statistics.
# > 2. Graph and summarize data using measures of Central Tendency and Variation
# > 3. Understand the characteristics of some common distributions such as Normal, Binomial, Uniform, and Exponential
# > 4. Work with bi-variate data and calculate summary statistics such as Correlation and Causation
# > 5. Understand the differences between working with samples and populations
# > 6. Define the Central Limit Theoreom and Law of Large Numbers
# > 7. Perform Hypothesis Testing
# > 8. Calculate Confidence Intervals

# %% [markdown]
# ## Statistics in Python

# %% [markdown]
# __Overview:__
# - Python has a wide range of useful functions to perform Statistical routines. These functions are found in the following two Modules:
# > 1. __[`scipy.stats`](https://docs.scipy.org/doc/scipy-0.18.1/reference/stats.html):__ The `stats` module in the SciPy Package offers many Statistical functions such as mean, zscore, correlation as well as other sub-modules for Continuous Distributions, Multivariate Distributions, and Discrete Distributions
# > 2. __[`numpy`](https://docs.scipy.org/doc/numpy-1.14.0/reference/routines.statistics.html):__ The `numpy` package itself offers many Statistical Functions such as Order Statistics, Averages and Variances, Correlating, and Histograms
#
# __Helpful Points:__
# 1. It is not necessary to access a sub-package within the `numpy` package like we did with `numpy.linalg`. Instead, we can simply execute the function directly from NumPy: `np.func_name`
#
# __Practice:__ Import the Statistics Modules in Python

# %% [markdown]
# ### Statistics Packages for Python

# %% [markdown]
# #### Importing the packages

# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import math 
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# autopep8   module    <module 'autopep8' from '<...>e-packages\\autopep8.py'>
# json       module    <module 'json' from 'c:\\<...>\lib\\json\\__init__.py'>
# math       module    <module 'math' (built-in)>
# np         module    <module 'numpy' from 'c:\<...>ges\\numpy\\__init__.py'>
# pd         module    <module 'pandas' from 'c:<...>es\\pandas\\__init__.py'>
# plt        module    <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# random     module    <module 'random' from 'c:<...>ython37\\lib\\random.py'>
# sns        module    <module 'seaborn' from 'c<...>s\\seaborn\\__init__.py'>
# stats      module    <module 'scipy.stats' fro<...>ipy\\stats\\__init__.py'>

# %% [markdown]
# #### Testing the packages

# %%
stats.describe([1,2,3,4,5]) # scipy stats sub-package
# Out:
# DescribeResult(nobs=5, minmax=(1, 5), mean=3.0, variance=2.5, skewness=0.0, kurtosis=-1.3)

# %%
stats.describe([1,2,3,4,5]).mean # checking just the mean with scipy stats
# Out:
# 3.0

# %%
np.mean([1,2,3,4,5]) # using numpy package
# Out:
# 3.0

# %% [markdown]
# ## Types of Statistics: Descriptive & Inferential

# %% [markdown]
# ### Descriptive Statistics
# Descriptive Statistics provides a summary of a set of data and its properties. It is important to understand that descriptive statistics simply collects and records metrics, nothing more.

# %% [markdown]
# ### Inferential Statistics
#
# The purpose on infrential statistics, as te name indicates, is to use data from a sa mple of a population in order to make inferences about the population itself.

# %% [markdown]
# #### A Closer look at Statistical Inference
#
# The world we live in is a complex, random, and uncertain process composed of many other processes. It is also a massive data-generating machine.
#
# Data represent traces of those real-world processes, and exactly which traces we gather are decided by our data collection or sampling method.
#
# We as scientists take interest in processes. An important step in our work is separating our process of interest from our data collection method. After separating the process from the data collection, we can see clearly that there are two sources of randomness and uncertainty. In particular, these are the uncertainty and randomness of the process itself, and the uncertainty of our collection methods.
#
# Part of the implication of this is that you can't just go around collecting data then immediately understand the processes of the world.
#
# In order to begin gaining this understanding you need to simplify those captured traces into something more comprehensible, to something that somehow captures it all in a much more concise way, and that something could be mathematical models or functions of the data, known as statistical estimators.
#
# More precisely, statistical inference is the discipline that concerns itself with the development of procedures, methods, and theorems that al‐ low us to extract meaning and information from data that has been generated by stochastic (random) processes.

# %% [markdown]
# ### Types of Data
#
# __Overview:__
# - In general, we can distinguish between two types of data:
# > 1. __[Qualitative Data](https://en.wikipedia.org/wiki/Qualitative_property):__ Qualitative Data contains discrete categories known as levels or categories. Qualitative Data can be further classified into four levels as described below:
# > 2. __[Quantitative Data](https://en.wikipedia.org/wiki/Quantitative_research):__ Quantitative Data is also known as Numerical Data because it contains numbers as counts or measurements

# %% [markdown]
# ### Graphing and Visualizing Data:

# %% [markdown]
# __Overview:__
# - Depending on the type of data there exists different types of graphs that we can use to explore the properties of the data
# > 1. __Qualitative Data:__ Qualitative Data can be summarized using the following methods:
# >> a. Frequency Table <br>
# >> b. Pie Charts <br>
# >> c. Bar Charts
# > 2. __Quantitative Data:__ Quantitative Data can be summarized using the following methods:
# >> a. Histograms <br>
# >> b. Scatter Plots <br>
# >> c. Line Graph
#
# __Helpful Points:__
# 1. There is lots of debate and best practices shared regarding the type of graph that should be chosen. Feel free to read about this online, but [here](https://blog.hubspot.com/marketing/types-of-graphs-for-data-visualization) is one such resource. We'll cover this in more depth later when we specifically cover Visualization
#
# __Practice:__ Examples of Graphing Data in Python

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %% [markdown]
# My hometown is Pittsburgh, PA which is located in Allegheny county. Let's play with an Allegheny County housing dataset!

# %%
# read in our data and the key for interpreting some of the values

ach_df = pd.read_csv('data/AlleghenyHousing/assessments.csv')

# %%
# reading this will return a UnicodeError unless we tell it how to decode the string values

ach_key_df = pd.read_csv('data/AlleghenyHousing/assessment_dictionary.csv', encoding = "ISO-8859-1")

# %%
#ach_key_df

# %% [markdown]
# We've gotten some very useful feedback. There are some mixed datatypes in some of our columns. It's probably a good guess that there are missing datapoints and therefore a mixture of numerical data and NaN values. We'll find out!

# %%
# view the first ten lines of the data
ach_df.head(10)
# Out:
#               PARID  PROPERTYHOUSENUM PROPERTYFRACTION PROPERTYADDRESS  \
# 0  0001G00224060300             151.0                   FORT PITT BLVD
# 1  0001G00224060400             151.0                   FORT PITT BLVD
# 2  0001G00224060500             151.0                   FORT PITT BLVD
# 3  0002M00222000000              40.0                     VAN BRAAM ST
# 4  0002M00223000000              42.0                     VAN BRAAM ST
# 5  0002M00224000000            1638.0                       FORBES AVE
# 6  0002M00225000000            1632.0                       FORBES AVE
# 7  0002M00227000000            1628.0                       FORBES AVE
# 8  0002M00228000000            1631.0                        TUSTIN ST
# 9  0002M00229000000            1626.0                       FORBES AVE
#
#   PROPERTYCITY PROPERTYSTATE PROPERTYUNIT  PROPERTYZIP  MUNICODE  \
# 0   PITTSBURGH            PA     UNIT 603      15222.0       101
# 1   PITTSBURGH            PA     UNIT 604      15222.0       101
# 2   PITTSBURGH            PA     UNIT 605      15222.0       101
# 3   PITTSBURGH            PA                   15219.0       101
# 4   PITTSBURGH            PA                   15219.0       101
# 5   PITTSBURGH            PA                   15219.0       101
# 6   PITTSBURGH            PA                   15219.0       101
# 7   PITTSBURGH            PA                   15219.0       101
# 8   PITTSBURGH            PA                   15219.0       101
# 9   PITTSBURGH            PA                   15219.0       101
#
#                  MUNIDESC  SCHOOLCODE  SCHOOLDESC  \
# 0  1st Ward  - PITTSBURGH          47  Pittsburgh
# 1  1st Ward  - PITTSBURGH          47  Pittsburgh
# 2  1st Ward  - PITTSBURGH          47  Pittsburgh
# 3  1st Ward  - PITTSBURGH          47  Pittsburgh
# 4  1st Ward  - PITTSBURGH          47  Pittsburgh
# 5  1st Ward  - PITTSBURGH          47  Pittsburgh
# 6  1st Ward  - PITTSBURGH          47  Pittsburgh
# 7  1st Ward  - PITTSBURGH          47  Pittsburgh
# 8  1st Ward  - PITTSBURGH          47  Pittsburgh
# 9  1st Ward  - PITTSBURGH          47  Pittsburgh
#
#                                               LEGAL1  \
# 0  FIRST SIDE CONDOMINIUM -  AMENDMENT OF DECLARA...
# 1  FIRST SIDE CONDOMINIUM -  AMENDMENT OF DECLARA...
# 2  FIRST SIDE CONDOMINIUM -  AMENDMENT OF DECLARA...
# 3    LOT 25X54 VAN BRAAM ST BET FORBES & TUSTIN STS
# 4    LOT 25X54 VAN BRAAM ST N W COR TUSTIN ST
# 5    LOT 24X70 FORBES ST
# 6    ARTHUR & NICHOLSON PLAN 16 LOT 24X120 FORBES AV
# 7    ARTHUR & NICHOLSON PLAN 1/2 OF 15 LOT 24X60 FOR
# 8    ARTHURS & NICHOLSON PLAN S 1/2 OF 15 LOT 24X60
# 9    ARTHURS & NICHALSONS PLAN 14 LOT 24X120 FORBES
#
#                                             LEGAL2  \
# 0                         UNIT 603 & PARKING SPACE
# 1                         UNIT 604 & PARKING SPACE
# 2                         UNIT 605 & PARKING SPACE
# 3  2 STY BRK HSE
# 4  2 STY M BRK HSE 42
# 5                                              NaN
# 6  E
# 7  BES AVE
# 8  TUSTIN ST
# 9  ST
#
#                                             LEGAL3 NEIGHCODE  \
# 0                                        6TH LEVEL    61P03H
# 1                                        6TH LEVEL    61P03H
# 2                                        6TH LEVEL    61P03H
# 3                                              NaN     10101
# 4                                              NaN     10101
# 5                                              NaN     51C04
# 6  2 STY BRK OFFICE 1632                               51C04
# 7  2 STY BRK DWLG & OFFICE 1628                        51C04
# 8                                              NaN     51C04
# 9  1 STY BSMT C B & BRK OFF BLDG 1626                  51C04
#
#                       NEIGHDESC TAXCODE       TAXDESC TAXSUBCODE  \
# 0                     151 FIRST       T  20 - Taxable        NaN
# 1                     151 FIRST       T  20 - Taxable        NaN
# 2                     151 FIRST       T  20 - Taxable        NaN
# 3  BLUFF DISTRICT OF PITTSBURGH       T  20 - Taxable        NaN
# 4  BLUFF DISTRICT OF PITTSBURGH       T  20 - Taxable        NaN
# 5              PITTSBURGH URBAN       T  20 - Taxable        NaN
# 6              PITTSBURGH URBAN       T  20 - Taxable        NaN
# 7              PITTSBURGH URBAN       T  20 - Taxable        NaN
# 8              PITTSBURGH URBAN       T  20 - Taxable        NaN
# 9              PITTSBURGH URBAN       T  20 - Taxable        NaN
#
#   TAXSUBCODE_DESC  OWNERCODE               OWNERDESC CLASS    CLASSDESC  \
# 0             NaN         12  REGULAR-ETUX OR ET VIR     R  RESIDENTIAL
# 1             NaN         11            REGULAR-ETAL     R  RESIDENTIAL
# 2             NaN         12  REGULAR-ETUX OR ET VIR     R  RESIDENTIAL
# 3             NaN         12  REGULAR-ETUX OR ET VIR     R  RESIDENTIAL
# 4             NaN         12  REGULAR-ETUX OR ET VIR     R  RESIDENTIAL
# 5             NaN         12  REGULAR-ETUX OR ET VIR     C   COMMERCIAL
# 6             NaN         20             CORPORATION     C   COMMERCIAL
# 7             NaN         20             CORPORATION     C   COMMERCIAL
# 8             NaN         20             CORPORATION     C   COMMERCIAL
# 9             NaN         12  REGULAR-ETUX OR ET VIR     C   COMMERCIAL
#
#    USECODE                 USEDESC  LOTAREA HOMESTEADFLAG FARMSTEADFLAG  \
# 0       50             CONDOMINIUM        0           HOM           NaN
# 1       50             CONDOMINIUM        0           HOM           NaN
# 2       50             CONDOMINIUM        0           NaN           NaN
# 3       10           SINGLE FAMILY     1350           NaN           NaN
# 4       10           SINGLE FAMILY     1350           NaN           NaN
# 5      456     PARKING GARAGE/LOTS     1680           NaN           NaN
# 6      447    OFFICE - 1-2 STORIES     2880           NaN           NaN
# 7      431  OFFICE/APARTMENTS OVER     1440           NaN           NaN
# 8      456     PARKING GARAGE/LOTS     1440           NaN           NaN
# 9      447    OFFICE - 1-2 STORIES     2880           NaN           NaN
#
#   CLEANGREEN ABATEMENTFLAG  RECORDDATE    SALEDATE  SALEPRICE SALECODE  \
# 0        NaN           NaN  10-05-2017  09-29-2017   699000.0       36
# 1        NaN           NaN  08-20-2012  08-20-2012   350000.0       AA
# 2        NaN           NaN  09-18-2009  09-18-2009   265000.0       UR
# 3        NaN           NaN         NaN  08-14-1995    25550.0        4
# 4        NaN           NaN         NaN  08-14-1995    45550.0        4
# 5        NaN           NaN         NaN  06-06-1984    85000.0        9
# 6        NaN           NaN  05-05-2017  05-03-2017   250000.0        H
# 7        NaN           NaN  11-10-2016  11-08-2016   113000.0        0
# 8        NaN           NaN  05-05-2017  05-03-2017   250000.0        H
# 9        NaN           NaN         NaN  12-17-1982    35000.0        0
#
#                     SALEDESC DEEDBOOK DEEDPAGE PREVSALEDATE  PREVSALEPRICE  \
# 0  QUIT CLAIM / SPEC WARRNTY    16966      186   10-25-2013       460000.0
# 1            SALE NOT ANALYZ    14983      438   08-23-2007       350000.0
# 2                OTHER VALID    14046      390   07-30-2007       235000.0
# 3                      OTHER     9518      404          NaN            NaN
# 4                      OTHER     9518      400          NaN            NaN
# 5              OTHER INVALID     6882      172          NaN            NaN
# 6            MULTI-PARCEL SA    16785      249   02-07-2013       170000.0
# 7                 VALID SALE    16602      379   04-21-1980        15000.0
# 8            MULTI-PARCEL SA    16785      249   02-07-2013       170000.0
# 9                 VALID SALE     6580      492          NaN            NaN
#
#   PREVSALEDATE2  PREVSALEPRICE2             CHANGENOTICEADDRESS1  \
# 0    08-23-2007        389745.0   151   FORT PITT BLVD  UNIT 603
# 1           NaN             NaN   151   FORT PITT BLVD  UNIT 604
# 2           NaN             NaN  151   FORT PITT BLVD  UNIT #605
# 3           NaN             NaN            203   EDELWEISS DR
# 4           NaN             NaN            203   EDELWEISS DR
# 5           NaN             NaN     307  S DITHRIDGE ST  APT 512
# 6    04-22-1992         55528.0           612   BOWER HILL RD
# 7           NaN             NaN                 PO BOX 13444
# 8    04-22-1992         55528.0           612   BOWER HILL RD
# 9           NaN             NaN             1626   FORBES AVE
#
#   CHANGENOTICEADDRESS2  CHANGENOTICEADDRESS3 CHANGENOTICEADDRESS4  \
# 0                            PITTSBURGH PA                  15222
# 1                            PITTSBURGH PA                  15222
# 2                            PITTSBURGH PA                  15222
# 3                       WEXFORD         PA                  15090
# 4                               WEXFORD PA                  15090
# 5                            PITTSBURGH PA                  15213
# 6                               VENETIA PA                  15367
# 7                            PITTSBURGH PA                  15243
# 8                               VENETIA PA                  15367
# 9                            PITTSBURGH PA                  15213
#
#    COUNTYBUILDING  COUNTYLAND  COUNTYTOTAL  COUNTYEXEMPTBLDG  LOCALBUILDING  \
# 0          592900           0       592900                 0         610900
# 1          295600           0       295600                 0         313600
# 2          227800           0       227800                 0         227800
# 3           15700        8900        24600                 0          15700
# 4           49100        8900        58000                 0          49100
# 5               0       11500        11500                 0              0
# 6          100000       50000       150000                 0         100000
# 7           15300       72000        87300                 0          15300
# 8            1000       13500        14500                 0           1000
# 9           13200      144000       157200                 0          13200
#
#    LOCALLAND  LOCALTOTAL  FAIRMARKETBUILDING  FAIRMARKETLAND  FAIRMARKETTOTAL  \
# 0          0      610900              610900               0           610900
# 1          0      313600              313600               0           313600
# 2          0      227800              227800               0           227800
# 3       8900       24600               15700            8900            24600
# 4       8900       58000               49100            8900            58000
# 5      11500       11500                   0           11500            11500
# 6      50000      150000              100000           50000           150000
# 7      72000       87300               15300           72000            87300
# 8      13500       14500                1000           13500            14500
# 9     144000      157200               13200          144000           157200
#
#   STYLE  STYLEDESC  STORIES  YEARBLT  EXTERIORFINISH EXTFINISH_DESC  ROOF  \
# 0    21   CONDO HR      1.0   2007.0             7.0       Concrete   4.0
# 1    21   CONDO HR      1.0   2007.0             7.0       Concrete   4.0
# 2    21   CONDO HR      1.0   2007.0             7.0       Concrete   4.0
# 3    16  OLD STYLE      2.0   1905.0             2.0          Brick   1.0
# 4    16  OLD STYLE      2.5   1905.0             2.0          Brick   1.0
# 5   NaN        NaN      NaN      NaN             NaN            NaN   NaN
# 6   NaN        NaN      NaN      NaN             NaN            NaN   NaN
# 7   NaN        NaN      NaN      NaN             NaN            NaN   NaN
# 8   NaN        NaN      NaN      NaN             NaN            NaN   NaN
# 9   NaN        NaN      NaN      NaN             NaN            NaN   NaN
#
#   ROOFDESC  BASEMENT BASEMENTDESC GRADE      GRADEDESC  CONDITION  \
# 0     ROLL       1.0         None    A+    VERY GOOD +        3.0
# 1     ROLL       1.0         None    A+    VERY GOOD +        3.0
# 2     ROLL       1.0         None    A+    VERY GOOD +        3.0
# 3  SHINGLE       5.0         Full     D  BELOW AVERAGE        4.0
# 4  SHINGLE       5.0         Full     C        AVERAGE        3.0
# 5      NaN       NaN          NaN   NaN            NaN        NaN
# 6      NaN       NaN          NaN   NaN            NaN        NaN
# 7      NaN       NaN          NaN   NaN            NaN        NaN
# 8      NaN       NaN          NaN   NaN            NaN        NaN
# 9      NaN       NaN          NaN   NaN            NaN        NaN
#
#   CONDITIONDESC  CDU  CDUDESC  TOTALROOMS  BEDROOMS  FULLBATHS  HALFBATHS  \
# 0       AVERAGE   AV  AVERAGE         5.0       2.0        2.0        0.0
# 1       AVERAGE   AV  AVERAGE         4.0       2.0        2.0        0.0
# 2       AVERAGE   AV  AVERAGE         3.0       1.0        1.0        1.0
# 3          FAIR   FR     FAIR         6.0       4.0        2.0        0.0
# 4       AVERAGE   FR     FAIR        12.0       6.0        2.0        0.0
# 5           NaN  NaN      NaN         NaN       NaN        NaN        NaN
# 6           NaN  NaN      NaN         NaN       NaN        NaN        NaN
# 7           NaN  NaN      NaN         NaN       NaN        NaN        NaN
# 8           NaN  NaN      NaN         NaN       NaN        NaN        NaN
# 9           NaN  NaN      NaN         NaN       NaN        NaN        NaN
#
#   HEATINGCOOLING    HEATINGCOOLINGDESC  FIREPLACES  BSMTGARAGE  \
# 0              B  Central Heat with AC         NaN         NaN
# 1              B  Central Heat with AC         NaN         NaN
# 2              B  Central Heat with AC         NaN         NaN
# 3              2          Central Heat         0.0         0.0
# 4              2          Central Heat         0.0         0.0
# 5            NaN                   NaN         NaN         NaN
# 6            NaN                   NaN         NaN         NaN
# 7            NaN                   NaN         NaN         NaN
# 8            NaN                   NaN         NaN         NaN
# 9            NaN                   NaN         NaN         NaN
#
#    FINISHEDLIVINGAREA  CARDNUMBER ALT_ID  TAXYEAR   ASOFDATE
# 0              1761.0         1.0    NaN     2018  01-SEP-18
# 1              1275.0         1.0    NaN     2018  01-SEP-18
# 2               888.0         1.0    NaN     2018  01-SEP-18
# 3              1200.0         1.0    NaN     2018  01-SEP-18
# 4              3225.0         1.0    NaN     2018  01-SEP-18
# 5                 NaN         NaN    NaN     2018  01-SEP-18
# 6                 NaN         NaN    NaN     2018  01-SEP-18
# 7                 NaN         NaN    NaN     2018  01-SEP-18
# 8                 NaN         NaN    NaN     2018  01-SEP-18
# 9                 NaN         NaN    NaN     2018  01-SEP-18

# %% [markdown]
# As we can see this data isn't very clean. There are mixed types in some columns and a whole lot of data that we simply don't want or need. We can handle this as we go.

# %% [markdown]
# This is probably a pretty big dataset. Maybe we should see how many rows we have in our dataframe.

# %%
len(ach_df)
# Out:
# 578221

# %% [markdown]
# Almost 600,000 rows of data, 86 columns. That's a lot of rows and columns, which is a good thing. It might just mean that we have a lot of cleaning to do and some of our operations take a minute or so to complete depending on how fast our machine is.

# %%
# lets convert the ASOFDATE column to datetime

ach_df['ASOFDATE'] = pd.to_datetime(ach_df['ASOFDATE'])

# %% [markdown]
# #### Graphing Qualitative Data

# %% [markdown]
# Lets check the datatypes of each column.

# %%
ach_df.dtypes
# Out:
# PARID                         object
# PROPERTYHOUSENUM             float64
# PROPERTYFRACTION              object
# PROPERTYADDRESS               object
# PROPERTYCITY                  object
# PROPERTYSTATE                 object
# PROPERTYUNIT                  object
# PROPERTYZIP                  float64
# MUNICODE                       int64
# MUNIDESC                      object
# SCHOOLCODE                     int64
# SCHOOLDESC                    object
# LEGAL1                        object
# LEGAL2                        object
# LEGAL3                        object
# NEIGHCODE                     object
# NEIGHDESC                     object
# TAXCODE                       object
# TAXDESC                       object
# TAXSUBCODE                    object
# TAXSUBCODE_DESC               object
# OWNERCODE                      int64
# OWNERDESC                     object
# CLASS                         object
# CLASSDESC                     object
# USECODE                        int64
# USEDESC                       object
# LOTAREA                        int64
# HOMESTEADFLAG                 object
# FARMSTEADFLAG                 object
#                            ...
# FAIRMARKETTOTAL                int64
# STYLE                         object
# STYLEDESC                     object
# STORIES                      float64
# YEARBLT                      float64
# EXTERIORFINISH               float64
# EXTFINISH_DESC                object
# ROOF                         float64
# ROOFDESC                      object
# BASEMENT                     float64
# BASEMENTDESC                  object
# GRADE                         object
# GRADEDESC                     object
# CONDITION                    float64
# CONDITIONDESC                 object
# CDU                           object
# CDUDESC                       object
# TOTALROOMS                   float64
# BEDROOMS                     float64
# FULLBATHS                    float64
# HALFBATHS                    float64
# HEATINGCOOLING                object
# HEATINGCOOLINGDESC            object
# FIREPLACES                   float64
# BSMTGARAGE                   float64
# FINISHEDLIVINGAREA           float64
# CARDNUMBER                   float64
# ALT_ID                        object
# TAXYEAR                        int64
# ASOFDATE              datetime64[ns]
# Length: 86, dtype: object

# %% [markdown]
# ##### Cleaning the data

# %% [markdown]
# Lets look at the feature key and see which feature we want to keep.

# %%
# tell pandas to output entire dataframe even if it's too big to fit on the screen
pd.set_option('display.max_rows', None) 

# print the dataframe
ach_key_df
# Out:
#               Field Name Data Type and Length  \
# 0                  PARID                  A30
# 1       PROPERTYHOUSENUM              NBR(10)
# 2       PROPERTYFRACTION                   A6
# 3        PROPERTYADDRESS                  A80
# 4           PROPERTYCITY                  A50
# 5          PROPERTYSTATE                  A50
# 6           PROPERTYUNIT                  A30
# 7            PROPERTYZIP                  A10
# 8               MUNICODE                   A5
# 9               MUNIDESC                  A50
# 10            SCHOOLCODE                  A30
# 11            SCHOOLDESC                  A50
# 12                LEGAL1                  A60
# 13                LEGAL2                  A60
# 14                LEGAL3                  A60
# 15             NEIGHCODE                   A8
# 16             NEIGHDESC                  A50
# 17               TAXCODE                   A1
# 18               TAXDESC                  A50
# 19            TAXSUBCODE                   A1
# 20       TAXSUBCODE_DESC                  A50
# 21             OWNERCODE                   A3
# 22             OWNERDESC                  A50
# 23                 CLASS                   A2
# 24             CLASSDESC                  A50
# 25               USECODE                   A4
# 26               USEDESC                  A50
# 27               LOTAREA               number
# 28         HOMESTEADFLAG                   A6
# 29            CLEANGREEN                   A3
# 30         FARMSTEADFLAG                   A6
# 31         ABATEMENTFLAG                   A6
# 32            RECORDDATE                  A10
# 33              SALEDATE                  A10
# 34             SALEPRICE               number
# 35              SALECODE                   A2
# 36              SALEDESC                  A50
# 37              DEEDBOOK                   A8
# 38              DEEDPAGE                   A8
# 39          PREVSALEDATE                  A10
# 40         PREVSALEPRICE               number
# 41         PREVSALEDATE2                  A10
# 42        PREVSALEPRICE2               number
# 43  CHANGENOTICEADDRESS1                 A100
# 44  CHANGENOTICEADDRESS2                 A100
# 45  CHANGENOTICEADDRESS3                 A100
# 46  CHANGENOTICEADDRESS4                 A100
# 47        COUNTYBUILDING               number
# 48            COUNTYLAND               number
# 49           COUNTYTOTAL               number
# 50      COUNTYEXEMPTBLDG               number
# 51         LOCALBUILDING               number
# 52             LOCALLAND               number
# 53            LOCALTOTAL               number
# 54    FAIRMARKETBUILDING               number
# 55        FAIRMARKETLAND               number
# 56       FAIRMARKETTOTAL               number
# 57                 STYLE                   A2
# 58             STYLEDESC                  A50
# 59               STORIES                   A3
# 60               YEARBLT               number
# 61        EXTERIORFINISH                   A2
# 62        EXTFINISH_DESC                  A50
# 63                  ROOF                  A20
# 64              ROOFDESC                  A50
# 65              BASEMENT                   A1
# 66          BASEMENTDESC                  A50
# 67                 GRADE                   A3
# 68             GRADEDESC                  A50
# 69             CONDITION                   A2
# 70         CONDITIONDESC                  A50
# 71                   CDU                   A2
# 72               CDUDESC                  A50
# 73            TOTALROOMS               number
# 74              BEDROOMS               number
# 75             FULLBATHS               number
# 76             HALFBATHS               number
# 77        HEATINGCOOLING                   A1
# 78    HEATINGCOOLINGDESC                  A50
# 79            FIREPLACES               number
# 80            BSMTGARAGE                   A1
# 81    FINISHEDLIVINGAREA               number
# 82            CARDNUMBER               number
# 83                ALT_ID                  A30
# 84               TAXYEAR               number
# 85              ASOFDATE                 date
#
#                                     Field Description  \
# 0                        Parcel Identification Number
# 1                      Property Location House Number
# 2             Property Location House Number Fraction
# 3                       Property Location Street Name
# 4                         Property Location City Name
# 5                        Property Location State Name
# 6                       Property Location Unit Number
# 7          Property Location Zip code, first 5 digits
# 8                    Municipality Code (Tax District)
# 9                                   Municipality Name
# 10                               School District Code
# 11                               School District Name
# 12                                Legal Description 1
# 13                                Legal Description 2
# 14                                Legal Description 3
# 15                                Neighborhood Number
# 16                                  Neighborhood Name
# 17                                         Tax Status
# 18                             Tax Status Description
# 19              Tax Sub Code  (applies to PURTA only)
# 20                           Tax Sub Code Description
# 21                                  Owner Type Code 1
# 22                                  Owner Description
# 23                                              Class
# 24                                  Class Description
# 25                                      Land Use Code
# 26                         Land Use Code Description
# 27                                Sum of Area of Land
# 28                                     Homestead Flag
# 29                               Clean and Green Flag
# 30                                     Farmstead Flag
# 31                                     Abatement Flag
# 32                                        Record Date
# 33                                          Sale Date
# 34                                         Sale Price
# 35                                 Sale Validity Code
# 36                     Sale Validity Code Description
# 37                                        Book Number
# 38                                        Page Number
# 39                                 Previous Sale Date
# 40                                Previous Sale Price
# 41                               Previous Sale Date 2
# 42                              Previous Sale Price 2
# 43                       Change Notice Full Address 1
# 44                       Change Notice Full Address 2
# 45                       Change Notice Full Address 3
# 46                       Change Notice Full Address 4
# 47                County Assessed Value for Building
# 48                     County Assessed Value for Land
# 49                        County Assessed Value Total
# 50                      County Exempt Building Amount
# 51                Local  Assessed Value for Building
# 52                      Local Assessed Value for Land
# 53                         Local Assessed Value Total
# 54                         Fair Market Building Value
# 55                             Fair Market Land Value
# 56                            Fair Market Total Value
# 57                     Dwelling - Architectural Style
# 58         Dwelling - Architectural Style Description
# 59                       Dwelling - Number of Stories
# 60                              Dwelling - Year Built
# 61                      Dwelling - Exterior Wall code
# 62               Dwelling - Exterior Wall Description
# 63                                    Dwelling - Roof
# 64                        Dwelling - Roof Description
# 65                                Dwelling - Basement
# 66                    Dwelling - Basement Description
# 67                                   Dwelling - Grade
# 68                       Dwelling - Grade Description
# 69                               Dwelling - Condition
# 70                   Dwelling - Condition Description
# 71                                     Dwelling - CDU
# 72                         Dwelling - CDU Description
# 73                             Dwelling - Total Rooms
# 74                                Dwelling - Bedrooms
# 75                              Dwelling - Full Baths
# 76                              Dwelling - Half Baths
# 77                         Dwelling - Heating Cooling
# 78             Dwelling - Heating Cooling Description
# 79  Dwelling - Number of Wood burning Fireplaces S...
# 80  Dwelling - Integral Basement Garage (Number of...
# 81        Dwelling - Total Square Feet of Living Area
# 82                  Dwelling - Building (card) Number
# 83             Alternate Parcel Identification Number
# 84                     The current certified tax year
# 85                          The run date of this file
#
#                                           Example 1           Example 2  \
# 0                                  0023S00162000000    1468J00244000000
# 1                                               514                  69
# 2                                               NaN                 -73
# 3                                         E OHIO ST          STROUSS RD
# 4                                        PITTSBURGH            IMPERIAL
# 5                                                PA                  PA
# 6                                               NaN                 NaN
# 7                                             15212               15126
# 8                                               123                 910
# 9                            23rd Ward - PITTSBURGH             Findlay
# 10                                               47                  43
# 11                               City Of Pittsburgh      West Allegheny
# 12  LOT 14.72X110.13 E OHIO ST BET JAMES & MIDDLE S              74 ALD
# 13                                                T         43.5656 ALD
# 14          3 STY BRK HSE 514                                    94 ALD
# 15                                            51C51               91004
# 16                                 PITTSBURGH URBAN               91004
# 17                                                E                   T
# 18                                      10 - Exempt        20 - Taxable
# 19                                              NaN                 NaN
# 20                                              NaN                 NaN
# 21                                               20                  11
# 22                                      CORPORATION        REGULAR-ETAL
# 23                                                C                   R
# 24                                       COMMERCIAL         RESIDENTIAL
# 25                                              404                  20
# 26                                  RETL/APT'S OVER          TWO FAMILY
# 27                                             1621             9215797
# 28                                              NaN                 HOM
# 29                                              NaN                   Y
# 30                                              NaN                 NaN
# 31                                              NaN                   Y
# 32                                       10/26/2012          12/23/2011
# 33                                       10/26/2012          12/23/2011
# 34                                            12129                   1
# 35                                                2                   3
# 36                                   CITY TREASURER      LOVE&AFFECTION
# 37                                             TR13               14772
# 38                                              475                 341
# 39                                       11/14/1980           2/17/2004
# 40                                            12500                   1
# 41                                              NaN           9/26/1984
# 42                                              NaN               76600
# 43                           414   GRANT ST  RM 200  69   STROUSS RD
# 44                            CITY-COUNTY BUILDING                  NaN
# 45                                  PITTSBURGH PA         IMPERIAL PA
# 46                                            15219               15126
# 47                                           81,700             139,300
# 48                                           53,000             114,700
# 49                                          134,700             254,000
# 50                                                0             150,000
# 51                                           81,700             307,300
# 52                                           53,000             114,700
# 53                                          134,700             422,000
# 54                                           81,700             307,300
# 55                                           53,000             316,200
# 56                                          134,700             623,500
# 57                                                9                  M1
# 58                                        TOWNHOUSE        MANUFACTURED
# 59                                                2                   1
# 60                                             1980                1979
# 61                                                1                   1
# 62                                            Frame               Frame
# 63                                                1                   3
# 64                                          SHINGLE               METAL
# 65                                                5                   2
# 66                                             Full          Slab/Piers
# 67                                                C                  D+
# 68                                          AVERAGE     BELOW AVERAGE +
# 69                                                3                   5
# 70                                          AVERAGE                POOR
# 71                                               AV                  PR
# 72                                          AVERAGE                POOR
# 73                                                7                   4
# 74                                                3                   2
# 75                                                1                   1
# 76                                                0                   0
# 77                                                2                   2
# 78                                     Central Heat        Central Heat
# 79                                                0                   0
# 80                                                0                   0
# 81                                              766                 660
# 82                                                2                   1
# 83                                              NaN    9910X00529000000
# 84                                             2015                2015
# 85                                        18-Jun-15           19-Jun-15
#
#                               Additional Data Details
# 0    A 16 character unique identifier for the parcel.
# 1   House Number for the  physical location of pro...
# 2   Continued House Number information for the  ph...
# 3   Street name for the  physical location of the ...
# 4      City where the property is physically located.
# 5     State where the property is physically located.
# 6   Unit numbers for the property, such as condo u...
# 7   Zip Code where the property is physically loca...
# 8   Municipality number associated with specified ...
# 9   Municipality name associated with specified pa...
# 10  School district number associated with specifi...
# 11  School district name associated with specified...
# 12  Line 1 of parcel legal description from the Deed.
# 13  Line 2 continuation of parcel legal descriptio...
# 14  Line 3 continuation of parcel legal descriptio...
# 15  The ID number for the valuation neighborhood c...
# 16  The name associated with the valuation neighbo...
# 17  Tax Status indicates whether or not real estat...
# 18  Description for Tax Status codes:  '10 - Exemp...
# 19  Tax Sub Code applies only to parcels having th...
# 20  Values:  E - 'PURTA - Exempt',  T - 'PURTA -Ta...
# 21  Numeric code categorizes owner as individuals ...
# 22  Descriptions for numeric owner codes.  [e.g. i...
# 23  Broad self-explanatory categories for describi...
# 24  Broad self-explanatory categories for describi...
# 25  More detailed than class, these categories fur...
# 26  More detailed than class, these categories fur...
# 27                      Total square footage of land.
# 28  A property owner may apply for a homestead red...
# 29  This field indicates that a parcel is receivin...
# 30  A property owner may apply for a farmstead red...
# 31  This field indicates that a parcel is receivin...
# 32  Date the sale was recorded \nin the Department...
# 33              Date the sale occurred  (mm/dd/yyyy).
# 34  Amount paid for the sale \n(also called the co...
# 35  A subjective categorization (code) as to wheth...
# 36  A subjective categorization (description) as t...
# 37  Cross-reference to the physical book number \n...
# 38  Page within the specified deed book \ncorrespo...
# 39     Date the previous sale occurred  (mm/dd/yyyy).
# 40                 Amount paid for the previous sale.
# 41  Date the 2nd previous sale occurred  (mm/dd/yy...
# 42             Amount paid for the 2nd previous sale.
# 43                  Address of owner of the property.
# 44                  Address of owner of the property.
# 45                  Address of owner of the property.
# 46                  Address of owner of the property.
# 47  The assessed property value of the building fo...
# 48  The assessed property value of the land for co...
# 49  The assessed property value (land and building...
# 50  The amount of assessment reduction granted on ...
# 51  The assessed property value of the building fo...
# 52  The assessed property value of the land for lo...
# 53  The assessed property value (land and building...
# 54  The base year appraised fair market value of t...
# 55  The base year appraised fair market value of t...
# 56  The base year appraised fair market value of l...
# 57                                The building style.
# 58                    Description for building style.
# 59  Refers to the story height of the main dwellin...
# 60                 The original date of construction.
# 61                            The exterior wall type.
# 62  Description of building material used for exte...
# 63                         The roofing material type.
# 64                   Description of roofing material.
# 65  This code describes the basement under the mai...
# 66       Description of basement type, if one exists.
# 67  Grade refers to quality of construction:\n\nA,...
# 68  Grade refers to quality of construction:\n\nA,...
# 69  Code for the overall physical condition or sta...
# 70  Description for the overall physical condition...
# 71  CDU is a composite rating for structures measu...
# 72  CDU is a composite rating for structures measu...
# 73  Total number of rooms in the main dwelling.  T...
# 74  The total number of separate rooms designed to...
# 75  A full bath has a toilet, sink and bathing fac...
# 76            A half bath has a toilet and sink only.
# 77     Code for the type of Heating / Cooling system.
# 78  Description for the type Heating / Cooling sys...
# 79  The number of wood-burning fireplace chimneys/...
# 80  The number of vehicle spaces available in a ga...
# 81  Finished living area, as measured from the out...
# 82  For parcels having more than one building only...
# 83  In tax year 2007, parcel ID numbers within cer...
# 84  The  applicable year for which real estate tax...
# 85                         The run date of this file.

# %% [markdown]
# We only need to be concerned with the following features:
#
# ```
# PARID
# PROPERTYZIP
# MUNICODE
# SCHOOLCODE
# NEIGHCODE
# OWNERCODE
# CLASS
# USECODE
# LOTAREA
# CLEANGREEN
# SALEDATE
# SALEPRICE
# SALECODE
# SALEDESC
# FAIRMARKETLAND
# FAIRMARKETBUILDING
# FAIRMARKETTOTAL
# COUNTYLAND
# COUNTRYBUILDING
# COUNTYTOTAL
# LOCALLAND
# LOCALBUILDING
# LOCALTOTAL
# STYLE
# STORIES
# YEARBLT
# EXTERIORFINISH
# ROOF
# BASMENT
# GRADE
# CONDITION
# TOTALROOMS
# FULLBATHS
# HALFBATHS
# HEATING
# COOLING
# FIREPLACES
# BSMNTGARAGE
# FINISHEDLIVINGAREA
# ```
#
# Essentially, we can drop all of the descriptions of each feature. Later on we can refer back to the feature codes once we've analyzed the data.

# %%
keep_cols = [
            # parced ID
            'PARID',
            
            # most recent sale information
            'SALEDATE',
            'SALEPRICE',
            'SALECODE',
            'SALEDESC',
    
            # appraisal and market values
            'FAIRMARKETLAND',
            'FAIRMARKETBUILDING',
            'FAIRMARKETTOTAL',
            'COUNTYLAND',
            'COUNTYBUILDING',
            'COUNTYTOTAL',
            'LOCALLAND',
            'LOCALBUILDING', 
            'LOCALTOTAL',
    
            # location information and etc.
            'PROPERTYZIP',
            'MUNICODE',
            'SCHOOLCODE',
            'NEIGHCODE',
            'OWNERCODE',
            'CLASS',
            'USECODE',
    
            # parcel / building features
            'LOTAREA',
            'STYLE',
            'STORIES',
            'YEARBLT',
            'EXTERIORFINISH',
            'ROOF',
            'BASMENT',
            'TOTALROOMS',
            'FULLBATHS',
            'HALFBATHS',
            'HEATING',
            'COOLING',
            'FIREPLACES',
            'BSMNTGARAGE',
            'FINISHEDLIVINGAREA']
ach_dfr = ach_df.filter(keep_cols, axis=1)

# %% [markdown]
# Something to note from working with a notebook is that Python is lazy--meaning that the new dataframe isn't created until `ach_dfr` is needed. Regardless, with this much data, this can take a while.
#
# Be sure to change the `maxrows` output back to a resonable number or you'll crash your browser trying to output a dataframe with 600,000 or so instances....

# %%
# tell pandas to output entire dataframe even if it's too big to fit on the screen
pd.set_option('display.max_rows', 50) 

# tell pandas to output all columns
pd.set_option('display.max_columns', None)

# %%
# show the dataframe sorted by order of sale date
ach_dfr.sort_values('SALEDATE')
# Out:
#                    PARID    SALEDATE  SALEPRICE SALECODE        SALEDESC  \
# 239667  0300A00165000000  01-01-1819        0.0        N  NOT APPLICABLE
# 298675  0424F00036000000  01-01-1846        0.0        N  NOT APPLICABLE
# 126006  0382K00061000000  01-01-1866        0.0        N  NOT APPLICABLE
# 369083  0212M00392000000  01-01-1871        0.0        3  LOVE&AFFECTION
# 229869  0606C00036000000  01-01-1877        0.0        N  NOT APPLICABLE
# 268638  0658D00080000000  01-01-1881        0.0        N  NOT APPLICABLE
# 318037  0616B00258000000  01-01-1894        0.0        N  NOT APPLICABLE
# 224177  0233B00119000000  01-01-1896        0.0        N  NOT APPLICABLE
# 318110  0616A00150000000  01-01-1897        0.0        N  NOT APPLICABLE
# 368822  0273J00245000000  01-01-1898        0.0        N  NOT APPLICABLE
# 216921  0643G00263000000  01-01-1898        0.0        N  NOT APPLICABLE
# 183687  0079E00082000000  01-01-1899        0.0        N  NOT APPLICABLE
# 130944  0381S00155000000  01-01-1900        0.0        3  LOVE&AFFECTION
# 462668  0113N00081000000  01-01-1900        0.0        3  LOVE&AFFECTION
# 306567  0874C00394000000  01-01-1900        0.0        N  NOT APPLICABLE
# 195991  0375N00108000000  01-01-1901        0.0        N  NOT APPLICABLE
# 476030  0455A00035000000  01-01-1904        0.0        N  NOT APPLICABLE
# 377515  0460D00014000000  01-01-1905        0.0      NaN             NaN
# 377459  0460G00152000000  01-01-1905        0.0        N  NOT APPLICABLE
# 527788  0379R00131000000  01-01-1906        0.0        N  NOT APPLICABLE
# 385983  0173D00119000000  01-01-1909        0.0        N  NOT APPLICABLE
# 234911  0305B00159000000  01-01-1910        0.0        N  NOT APPLICABLE
# 58534   0032M00303000000  01-01-1911        0.0        N  NOT APPLICABLE
# 514097  0063D00150000000  01-01-1911        0.0        3  LOVE&AFFECTION
# 58533   0032M00298000000  01-01-1911        0.0        N  NOT APPLICABLE
# ...                  ...         ...        ...      ...             ...
# 573282  8000T03151000000         NaN        NaN      NaN             NaN
# 573283  8000T03157000000         NaN        NaN      NaN             NaN
# 573332  0634S00044000000         NaN        NaN      NaN             NaN
# 573409  0111D00350000000         NaN        NaN      NaN             NaN
# 573495  0473A00057000000         NaN        NaN      NaN             NaN
# 573994  0732N00280000000         NaN        NaN      NaN             NaN
# 574172  0049J00118020500         NaN        NaN      NaN             NaN
# 574314  0080C00087000300         NaN        NaN      NaN             NaN
# 574569  0004L00226000000         NaN        NaN      NaN             NaN
# 574638  0077B00226000000         NaN        NaN      NaN             NaN
# 574873  0113D00132030400         NaN        NaN      NaN             NaN
# 575808  0662D00013000000         NaN        NaN      NaN             NaN
# 575983  8000T01153000000         NaN        NaN      NaN             NaN
# 575984  8000T01160000000         NaN        NaN      NaN             NaN
# 576085  1569K00223000000         NaN        NaN      NaN             NaN
# 576158  1180L00124000000         NaN        NaN      NaN             NaN
# 576527  2178K00008000000         NaN        NaN      NaN             NaN
# 576692  8000T02229000000         NaN        NaN      NaN             NaN
# 576696  8000T04798000000         NaN        NaN      NaN             NaN
# 576698  8000T02862000000         NaN        NaN      NaN             NaN
# 576974  8000T03013000000         NaN        NaN      NaN             NaN
# 577049  8000T01340000000         NaN        NaN      NaN             NaN
# 577268  8000T02832000000         NaN        NaN      NaN             NaN
# 577586  1272B00396000000         NaN        NaN      NaN             NaN
# 577823  0692S00044000000         NaN        NaN      NaN             NaN
#
#         FAIRMARKETLAND  FAIRMARKETBUILDING  FAIRMARKETTOTAL  COUNTYLAND  \
# 239667             200                   0              200         200
# 298675           13800                   0            13800       13800
# 126006            4000                   0             4000        4000
# 369083            1300                8000             9300        1300
# 229869          400000               20000           420000       27600
# 268638           53500                   0            53500       53500
# 318037           29800                   0            29800       29800
# 224177             800                   0              800         800
# 318110             200                   0              200         200
# 368822           81900                   0            81900       81900
# 216921            8800                   0             8800        8800
# 183687           22300                   0            22300       22300
# 130944           14900              828200           843100       14900
# 462668           20000               15800            35800       20000
# 306567           13200                   0            13200       13200
# 195991            2000                   0             2000        2000
# 476030             500                   0              500         500
# 377515           18000                   0            18000       18000
# 377459           14900                   0            14900       14900
# 527788             600                   0              600         600
# 385983           10200                   0            10200       10200
# 234911            1300                   0             1300        1300
# 58534            12400                   0            12400       12400
# 514097           17600                   0            17600       17600
# 58533            12000                   0            12000       12000
# ...                ...                 ...              ...         ...
# 573282               0                3700             3700           0
# 573283               0                5800             5800           0
# 573332           12600               41700            54300       12600
# 573409           20100               87700           107800       20100
# 573495           41300              117400           158700       41300
# 573994          118800              393800           512600       23780
# 574172            5000                   0             5000        5000
# 574314               0               72000            72000           0
# 574569            9500               40900            50400        9500
# 574638            8800               23700            32500        8800
# 574873               0              110000           110000           0
# 575808           45600              272400           318000       45600
# 575983               0               17900            17900           0
# 575984               0               19500            19500           0
# 576085           40000              144100           184100       40000
# 576158           44600              161600           206200       44600
# 576527          285000             2237700          2522700       37300
# 576692               0                4500             4500           0
# 576696               0               39900            39900           0
# 576698               0                4900             4900           0
# 576974               0                2500             2500           0
# 577049               0               21000            21000           0
# 577268               0                3100             3100           0
# 577586           11700                   0            11700       11700
# 577823           36400              185900           222300       36400
#
#         COUNTYBUILDING  COUNTYTOTAL  LOCALLAND  LOCALBUILDING  LOCALTOTAL  \
# 239667               0          200        200              0         200
# 298675               0        13800      13800              0       13800
# 126006               0         4000       4000              0        4000
# 369083            8000         9300       1300           8000        9300
# 229869            2000        29600      27600          20000       47600
# 268638               0        53500      53500              0       53500
# 318037               0        29800      29800              0       29800
# 224177               0          800        800              0         800
# 318110               0          200        200              0         200
# 368822               0        81900      81900              0       81900
# 216921               0         8800       8800              0        8800
# 183687               0        22300      22300              0       22300
# 130944          828200       843100      14900         828200      843100
# 462668           15800        35800      20000          15800       35800
# 306567               0        13200      13200              0       13200
# 195991               0         2000       2000              0        2000
# 476030               0          500        500              0         500
# 377515               0        18000      18000              0       18000
# 377459               0        14900      14900              0       14900
# 527788               0          600        600              0         600
# 385983               0        10200      10200              0       10200
# 234911               0         1300       1300              0        1300
# 58534                0        12400      12400              0       12400
# 514097               0        17600      17600              0       17600
# 58533                0        12000      12000              0       12000
# ...                ...          ...        ...            ...         ...
# 573282               0            0          0           3700        3700
# 573283            5800         5800          0           5800        5800
# 573332           41700        54300      12600          41700       54300
# 573409           69700        89800      20100          87700      107800
# 573495           99400       140700      41300         117400      158700
# 573994           78840       102620      23780          78840      102620
# 574172               0         5000       5000              0        5000
# 574314           72000        72000          0          72000       72000
# 574569           40900        50400       9500          40900       50400
# 574638           23700        32500       8800          23700       32500
# 574873          110000       110000          0         110000      110000
# 575808          254400       300000      45600         272400      318000
# 575983               0            0          0          17900       17900
# 575984            1500         1500          0          19500       19500
# 576085          126100       166100      40000         144100      184100
# 576158          161600       206200      44600         161600      206200
# 576527         2237700      2275000      37300        2237700     2275000
# 576692               0            0          0           4500        4500
# 576696           39900        39900          0          39900       39900
# 576698               0            0          0           4900        4900
# 576974               0            0          0           2500        2500
# 577049            3000         3000          0          21000       21000
# 577268            3100         3100          0           3100        3100
# 577586               0        11700      11700              0       11700
# 577823          167900       204300      36400         185900      222300
#
#         PROPERTYZIP  MUNICODE  SCHOOLCODE NEIGHCODE  OWNERCODE CLASS  USECODE  \
# 239667      15221.0       872           9     87202         10     R      100
# 298675      15143.0       901          32     90102         10     R      100
# 126006      15132.0       403          23     40011         10     R      100
# 369083      15225.0       928          11     53C36         20     G      630
# 229869      15143.0       869          32     86901         10     F      101
# 268638      15025.0       878          44     87803         10     R      100
# 318037      15101.0       914          20     91404         10     R      100
# 224177      15221.0       866          46     86606         10     R      100
# 318110      15101.0       914          20     91404         10     R      100
# 368822      15225.0       928          11     92801         10     F      110
# 216921      15148.0       861          14     86101         10     R      100
# 183687      15209.0       838          34     83802         10     R      100
# 130944      15132.0       409          23     53C48         20     G      650
# 462668      15136.0       949          39     53C26         20     G      650
# 306567      15135.0       908          16     90804         10     R      100
# 195991      15104.0       843           9     84302         10     R      100
# 476030      15145.0       953           9     95305         10     F      112
# 377515      15137.0       930          14     93004         10     R      100
# 377459      15137.0       930          14     93004         10     R      100
# 527788      15132.0       408          23     40012         10     R      100
# 385983      15235.0       934          30     93406         10     R      100
# 234911      15122.0       870          45     87004         10     R      100
# 58534       15210.0       116          47     11603         10     R      100
# 514097      15216.0       120          47     12002         20     G      640
# 58533       15210.0       116          47     11603         10     R      100
# ...             ...       ...         ...       ...        ...   ...      ...
# 573282      15205.0       939          24     939T1         10     R       90
# 573283      15205.0       939          24     939T1         12     R       90
# 573332      15235.0       934          30     93403         10     R       10
# 573409      15136.0       949          39     94901         10     R       10
# 573495      15236.0       945          37     94501         12     R       10
# 573994      15144.0       853           1     53C11         20     C      685
# 574172      15201.0       106          47     61P26         20     R      111
# 574314      15201.0       110          47     61P03         20     R       50
# 574569      15211.0       118          47     11803         20     R       70
# 574638      15214.0       126          47     12602         20     R       70
# 574873      15202.0       803          29     61N04         20     R       50
# 575808      15025.0       878          44     87802         12     R       10
# 575983      15106.0       905           8     905T1         12     R       90
# 575984      15106.0       905           8     905T1         12     R       90
# 576085      15083.0       908          16     90802         12     R       10
# 576158      15026.0       910          43     91002         20     R       60
# 576527      15005.0       923          27     92305         10     R       10
# 576692      15071.0       929          43     929T1         10     R       90
# 576696      15126.0       929          43     939T2         20     R       90
# 576698      15071.0       929          43     929T6         10     R       90
# 576974      15044.0       938           3     938T2         10     R       90
# 577049      15106.0       939          24     905T1         12     R       90
# 577268      15126.0       929          43     929T2         10     R       90
# 577586      15037.0       825          16     53U01         21     U      840
# 577823      15108.0       929          43     92903         12     R       10
#
#         LOTAREA STYLE  STORIES  YEARBLT  EXTERIORFINISH  ROOF  TOTALROOMS  \
# 239667     1940   NaN      NaN      NaN             NaN   NaN         NaN
# 298675    39238   NaN      NaN      NaN             NaN   NaN         NaN
# 126006     4956   NaN      NaN      NaN             NaN   NaN         NaN
# 369083     1457   NaN      NaN      NaN             NaN   NaN         NaN
# 229869   522720    16      1.5   1940.0             2.0   1.0         5.0
# 268638   101930   NaN      NaN      NaN             NaN   NaN         NaN
# 318037    11860   NaN      NaN      NaN             NaN   NaN         NaN
# 224177     3375   NaN      NaN      NaN             NaN   NaN         NaN
# 318110     2500   NaN      NaN      NaN             NaN   NaN         NaN
# 368822  2080861   NaN      NaN      NaN             NaN   NaN         NaN
# 216921    13920   NaN      NaN      NaN             NaN   NaN         NaN
# 183687    94917   NaN      NaN      NaN             NaN   NaN         NaN
# 130944     8636   NaN      NaN      NaN             NaN   NaN         NaN
# 462668    21736   NaN      NaN      NaN             NaN   NaN         NaN
# 306567   566825   NaN      NaN      NaN             NaN   NaN         NaN
# 195991     5000   NaN      NaN      NaN             NaN   NaN         NaN
# 476030     5000   NaN      NaN      NaN             NaN   NaN         NaN
# 377515     5000   NaN      NaN      NaN             NaN   NaN         NaN
# 377459     3267   NaN      NaN      NaN             NaN   NaN         NaN
# 527788     2750   NaN      NaN      NaN             NaN   NaN         NaN
# 385983     6652   NaN      NaN      NaN             NaN   NaN         NaN
# 234911     4015   NaN      NaN      NaN             NaN   NaN         NaN
# 58534     31875   NaN      NaN      NaN             NaN   NaN         NaN
# 514097    23225   NaN      NaN      NaN             NaN   NaN         NaN
# 58533     27402   NaN      NaN      NaN             NaN   NaN         NaN
# ...         ...   ...      ...      ...             ...   ...         ...
# 573282        0    M1      1.0   1993.0             1.0   3.0         5.0
# 573283        0    M1      1.0   1978.0             1.0   3.0         6.0
# 573332    11466     5      1.0   1958.0             2.0   1.0         5.0
# 573409     6607     1      1.0   1961.0             2.0   1.0         7.0
# 573495    10039     2      1.0   1960.0             2.0   1.0         6.0
# 573994    40000    16      2.0   1890.0             1.0   1.0         7.0
# 574172        0    22      1.0   2016.0             2.0   4.0         4.0
# 574314     1190    27      1.0   1920.0             2.0   4.0         3.0
# 574569     1629    12      2.0   1920.0             1.0   1.0         6.0
# 574638     1920    12      2.0   1925.0             2.0   4.0         5.0
# 574873        0    27      1.0   1905.0             2.0   4.0         4.0
# 575808    26136     4      2.0   2004.0             2.0   1.0         8.0
# 575983        0    M2      1.0   1990.0             1.0   1.0         5.0
# 575984        0    M2      1.0   1990.0             1.0   1.0         5.0
# 576085    73830     1      1.0   2016.0             1.0   1.0         7.0
# 576158     7475     9      2.0   2016.0             1.0   1.0         6.0
# 576527  3002552     7      1.0   2002.0             4.0   2.0         9.0
# 576692        0    M1      1.0   1982.0             1.0   1.0         4.0
# 576696        0    M1      1.0   2017.0             1.0   1.0         5.0
# 576698        0    M1      1.0   1994.0             1.0   1.0         4.0
# 576974        0    M1      1.0   1970.0             1.0   3.0         4.0
# 577049        0    M2      1.0   1998.0             1.0   1.0         5.0
# 577268        0    M1      1.0   1971.0             1.0   3.0         4.0
# 577586   254643   NaN      NaN      NaN             NaN   NaN         NaN
# 577823    20070     4      2.0   1999.0             6.0   1.0         8.0
#
#         FULLBATHS  HALFBATHS  FIREPLACES  FINISHEDLIVINGAREA
# 239667        NaN        NaN         NaN                 NaN
# 298675        NaN        NaN         NaN                 NaN
# 126006        NaN        NaN         NaN                 NaN
# 369083        NaN        NaN         NaN                 NaN
# 229869        1.0        1.0         1.0              1330.0
# 268638        NaN        NaN         NaN                 NaN
# 318037        NaN        NaN         NaN                 NaN
# 224177        NaN        NaN         NaN                 NaN
# 318110        NaN        NaN         NaN                 NaN
# 368822        NaN        NaN         NaN                 NaN
# 216921        NaN        NaN         NaN                 NaN
# 183687        NaN        NaN         NaN                 NaN
# 130944        NaN        NaN         NaN                 NaN
# 462668        NaN        NaN         NaN                 NaN
# 306567        NaN        NaN         NaN                 NaN
# 195991        NaN        NaN         NaN                 NaN
# 476030        NaN        NaN         NaN                 NaN
# 377515        NaN        NaN         NaN                 NaN
# 377459        NaN        NaN         NaN                 NaN
# 527788        NaN        NaN         NaN                 NaN
# 385983        NaN        NaN         NaN                 NaN
# 234911        NaN        NaN         NaN                 NaN
# 58534         NaN        NaN         NaN                 NaN
# 514097        NaN        NaN         NaN                 NaN
# 58533         NaN        NaN         NaN                 NaN
# ...           ...        ...         ...                 ...
# 573282        1.0        0.0         0.0               684.0
# 573283        1.0        1.0         0.0              1148.0
# 573332        1.0        0.0         0.0               900.0
# 573409        2.0        1.0         1.0              1520.0
# 573495        2.0        1.0         1.0              1656.0
# 573994        1.0        1.0         0.0              2645.0
# 574172        2.0        0.0         NaN              1152.0
# 574314        1.0        1.0         NaN               665.0
# 574569        1.0        0.0         NaN              1444.0
# 574638        1.0        0.0         NaN              1200.0
# 574873        1.0        1.0         NaN              1310.0
# 575808        2.0        1.0         1.0              3159.0
# 575983        2.0        0.0         0.0              2064.0
# 575984        2.0        0.0         0.0              2019.0
# 576085        1.0        1.0         NaN              2040.0
# 576158        2.0        1.0         NaN              1560.0
# 576527        4.0        2.0         2.0             14362.0
# 576692        1.0        0.0         0.0               924.0
# 576696        2.0        0.0         NaN              1352.0
# 576698        1.0        0.0         0.0               924.0
# 576974        1.0        0.0         0.0               744.0
# 577049        2.0        0.0         0.0              1568.0
# 577268        1.0        0.0         0.0               924.0
# 577586        NaN        NaN         NaN                 NaN
# 577823        2.0        1.0         0.0              1872.0
#
# [578221 rows x 32 columns]

# %% [markdown]
# Now we can drop:
#  - any instances that don't have an actual building on them
#  - everything that wasn't a `VALID SALE` or an `OTHER VALID` in the `SALEDESD` column
#
# This nice list comprehension came from: https://stackoverflow.com/questions/13851535/how-to-delete-rows-from-a-pandas-dataframe-based-on-a-conditional-expression

# %%
ach_dfr = ach_dfr[ach_dfr['FAIRMARKETBUILDING'] > 0]
ach_dfr = ach_dfr[ach_dfr['SALEDESC'] == "VALID SALE"].append(ach_dfr[ach_dfr['SALEDESC'] == "OTHER VALID"])

# %%
ach_dfr
# Out:
#                    PARID    SALEDATE  SALEPRICE SALECODE     SALEDESC  \
# 7       0002M00227000000  11-08-2016   113000.0        0   VALID SALE
# 9       0002M00229000000  12-17-1982    35000.0        0   VALID SALE
# 11      0002M00234000000  03-15-1982    10667.0        0   VALID SALE
# 12      0002M00234000A00  03-15-1982     5334.0        0   VALID SALE
# 14      0002M00238000000  11-16-1988    20000.0        0   VALID SALE
# 16      0002M00243000000  06-24-1988    26250.0        0   VALID SALE
# 49      0002L00025000000  07-30-2004  1000000.0        0   VALID SALE
# 75      0002P00110000000  07-24-1992   400000.0        0   VALID SALE
# 77      0002P00122000000  08-18-2005  1220000.0        0   VALID SALE
# 101     0001D00115000000  12-10-1979   255000.0        0   VALID SALE
# 104     0001D00128000000  07-15-1981   315000.0        0   VALID SALE
# 108     0001D00144000000  12-29-2000   350000.0        0   VALID SALE
# 110     0001D00150000000  04-20-2007   257000.0        0   VALID SALE
# 134     0001G00128000000  03-12-2007   400000.0        0   VALID SALE
# 137     0001G00151000000  12-31-1992  7333050.0        0   VALID SALE
# 141     0001G00198000000  11-01-1994   110000.0        0   VALID SALE
# 143     0001G00204000000  02-03-1993   333000.0        0   VALID SALE
# 148     0001G00212000000  08-05-1987   315000.0        0   VALID SALE
# 151     0001G00224040100  11-15-2007   525000.0        0   VALID SALE
# 156     0001G00224050100  07-09-2014   425000.0        0   VALID SALE
# 159     0001G00224050400  08-28-2013   300000.0        0   VALID SALE
# 160     0001G00224050500  09-15-2017   315000.0        0   VALID SALE
# 166     0001H00213000000  01-05-2011   550000.0        0   VALID SALE
# 173     0001H00283000000  05-22-1998   180000.0        0   VALID SALE
# 174     0001H00286000000  02-21-2007   258296.0        0   VALID SALE
# ...                  ...         ...        ...      ...          ...
# 578066  0590E00019000000  03-12-1997   137150.0        U  OTHER VALID
# 578069  0590L00001000000  02-25-2011   231000.0       UR  OTHER VALID
# 578074  0323J00065000000  06-03-2011   180000.0       UR  OTHER VALID
# 578081  0324L00158000000  10-30-2001   157647.0        U  OTHER VALID
# 578086  0590P00112000000  10-06-2003   110000.0        U  OTHER VALID
# 578088  0590S00013000000  07-30-2016   125000.0       UR  OTHER VALID
# 578100  0325M00032000000  07-28-2016    83000.0       UR  OTHER VALID
# 578109  0691H00012000000  05-21-1998   160000.0        U  OTHER VALID
# 578112  0691L00083000000  06-22-2000    74000.0        U  OTHER VALID
# 578124  0691L00090000000  03-21-1997    76900.0        U  OTHER VALID
# 578125  0691M00008000000  06-28-1996   141000.0        U  OTHER VALID
# 578136  0481R00027000000  11-27-1996    75000.0        U  OTHER VALID
# 578139  0489L00006000000  07-13-2001   129727.0        U  OTHER VALID
# 578141  0488M00015000000  10-10-2017   349000.0       UR  OTHER VALID
# 578142  0572G00028000000  09-03-2003    89000.0        U  OTHER VALID
# 578153  0573D00046000000  06-23-2003    85000.0        U  OTHER VALID
# 578162  1357G00150000000  08-01-2014   200000.0       UR  OTHER VALID
# 578168  1999S00003000000  11-23-1999   107300.0        U  OTHER VALID
# 578171  0146F00045000000  10-21-2010   238239.0       UR  OTHER VALID
# 578174  0323J00011000000  06-04-2009   315000.0       UR  OTHER VALID
# 578177  0590G00070000000  07-28-2008   317526.0       UR  OTHER VALID
# 578186  0691L00072000000  05-19-2003    99900.0        U  OTHER VALID
# 578193  0198L00015000000  10-11-2017   650000.0       UR  OTHER VALID
# 578201  0404L00015000000  07-29-2008   257548.0       UR  OTHER VALID
# 578207  0496E00003000000  10-26-2000    90000.0        U  OTHER VALID
#
#         FAIRMARKETLAND  FAIRMARKETBUILDING  FAIRMARKETTOTAL  COUNTYLAND  \
# 7                72000               15300            87300       72000
# 9               144000               13200           157200      144000
# 11                8400               17500            25900        7900
# 12                4200               10000            14200        4200
# 14              123800               53000           176800      123800
# 16              105600               30800           136400      105600
# 49             1100000            26413200         27513200       22000
# 75               74600                9500            84100       74600
# 77              527200             3333800          3861000      527200
# 101             155900              177500           333400      155900
# 104             288000              175300           463300      288000
# 108             173400              208500           381900      173400
# 110             530800              395500           926300      530800
# 134             216200                3800           220000      216200
# 137            7000000             1405000          8405000     7000000
# 141             128000              105800           233800      128000
# 143             280000              233100           513100      280000
# 148             117600              282400           400000      117600
# 151                  0              343400           343400           0
# 156                  0              385900           385900           0
# 159                  0              313600           313600           0
# 160                  0              222800           222800           0
# 166             205000              452500           657500      205000
# 173             164200              113200           277400      164200
# 174             135000              325000           460000      135000
# ...                ...                 ...              ...         ...
# 578066           26800              151500           178300       26800
# 578069           40000              191000           231000       40000
# 578074           24900              147000           171900       24900
# 578081           24800              137300           162100       24800
# 578086           23800               82200           106000       23800
# 578088           35400               96900           132300       35400
# 578100           19500               65500            85000       19500
# 578109           35500              139300           174800       35500
# 578112           35400               67100           102500       35400
# 578124           23900               82600           106500       23900
# 578125           35500              143400           178900       35500
# 578136           23100               79900           103000       23100
# 578139           31900              105300           137200       31900
# 578141           62000              282800           344800       62000
# 578142           22600               82100           104700       22600
# 578153           22600               75000            97600       22600
# 578162               0              185900           185900           0
# 578168          103100               87400           190500      103100
# 578171           63800              157300           221100       63800
# 578174           45100              251000           296100       45100
# 578177           40100              233500           273600       40100
# 578186           26200               84600           110800       26200
# 578193           90600              592500           683100       90600
# 578201           30500              200800           231300       30500
# 578207           30400               94600           125000       30400
#
#         COUNTYBUILDING  COUNTYTOTAL  LOCALLAND  LOCALBUILDING  LOCALTOTAL  \
# 7                15300        87300      72000          15300       87300
# 9                13200       157200     144000          13200      157200
# 11                   0         7900       8400          17500       25900
# 12               10000        14200       4200          10000       14200
# 14               53000       176800     123800          53000      176800
# 16               30800       136400     105600          30800      136400
# 49              528260       550260      22000         528260      550260
# 75                9500        84100      74600           9500       84100
# 77             3333800      3861000     527200        3333800     3861000
# 101             177500       333400     155900         177500      333400
# 104             175300       463300     288000         175300      463300
# 108             208500       381900     173400         208500      381900
# 110             323890       854690     530800         395500      926300
# 134               3800       220000     216200           3800      220000
# 137            1405000      8405000    7000000        1405000     8405000
# 141             105800       233800     128000         105800      233800
# 143             233100       513100     280000         233100      513100
# 148             282400       400000     117600         282400      400000
# 151             325400       325400          0         343400      343400
# 156             367900       367900          0         385900      385900
# 159             295600       295600          0         313600      313600
# 160             222800       222800          0         222800      222800
# 166             452500       657500     205000         452500      657500
# 173             113200       277400     164200         113200      277400
# 174             235365       370365     135000         325000      460000
# ...                ...          ...        ...            ...         ...
# 578066          133500       160300      26800         151500      178300
# 578069          173000       213000      40000         191000      231000
# 578074          129000       153900      24900         147000      171900
# 578081          119300       144100      24800         137300      162100
# 578086           64200        88000      23800          82200      106000
# 578088           96900       132300      35400          96900      132300
# 578100           65500        85000      19500          65500       85000
# 578109          121300       156800      35500         139300      174800
# 578112           49100        84500      35400          67100      102500
# 578124           64600        88500      23900          82600      106500
# 578125          143400       178900      35500         143400      178900
# 578136           61900        85000      23100          79900      103000
# 578139           87300       119200      31900         105300      137200
# 578141          264800       326800      62000         282800      344800
# 578142           64100        86700      22600          82100      104700
# 578153           57000        79600      22600          75000       97600
# 578162          167900       167900          0         185900      185900
# 578168           69400       172500     103100          87400      190500
# 578171          139300       203100      63800         157300      221100
# 578174          233000       278100      45100         251000      296100
# 578177          215500       255600      40100         233500      273600
# 578186           66600        92800      26200          84600      110800
# 578193          592500       683100      90600         592500      683100
# 578201          182800       213300      30500         200800      231300
# 578207           94600       125000      30400          94600      125000
#
#         PROPERTYZIP  MUNICODE  SCHOOLCODE NEIGHCODE  OWNERCODE CLASS  USECODE  \
# 7           15219.0       101          47     51C04         20     C      431
# 9           15219.0       101          47     51C04         12     C      447
# 11          15219.0       101          47     10101         10     R       20
# 12          15219.0       101          47     10101         10     R       70
# 14          15219.0       101          47    51C04B         10     C      455
# 16          15219.0       101          47    51C04B         10     C      455
# 49          15219.0       101          47     51C01         20     C      456
# 75          15219.0       101          47     51C21         20     C      456
# 77          15219.0       101          47     51C02         20     C      419
# 101         15222.0       101          47     51C01         12     C      406
# 104         15222.0       101          47     51C01         10     C      405
# 108         15222.0       101          47     51C01         20     C      430
# 110         15222.0       101          47     51C01         20     C      404
# 134         15222.0       101          47     51C02         20     C      456
# 137         15222.0       101          47     51C01         20     C      449
# 141         15222.0       101          47     51C02         12     C      448
# 143         15222.0       101          47     51C02         20     C      447
# 148         15222.0       101          47     51C02         20     C      449
# 151         15222.0       101          47    61P03H         10     R       50
# 156         15222.0       101          47    61P03H         12     R       50
# 159         15222.0       101          47    61P03H         11     R       50
# 160         15222.0       101          47    61P03H         10     R       50
# 166         15222.0       101          47     51C01         20     C      430
# 173         15222.0       101          47     51C01         10     C      353
# 174         15222.0       101          47     51C01         20     C      404
# ...             ...       ...         ...       ...        ...   ...      ...
# 578066      15126.0       929          43     92903         12     R       10
# 578069      15071.0       929          43     92902         12     R       10
# 578074      15017.0       946          36     94602         10     R       60
# 578081      15017.0       946          36     94602         10     R       60
# 578086      15071.0       929          43     92903         10     R       60
# 578088      15071.0       929          43     92903         12     R       10
# 578100      15064.0       946          36     94605         10     R       10
# 578109      15126.0       929          43     92903         12     R       10
# 578112      15126.0       929          43     92903         10     R       60
# 578124      15126.0       929          43     92903         10     R       60
# 578125      15126.0       929          43     92903         12     R       10
# 578136      15017.0       946          36     94603         10     R       60
# 578139      15057.0       946          36     94604         10     R       10
# 578141      15057.0       946          36     94602         10     R       10
# 578142      15017.0       946          36     94603         10     R       60
# 578153      15017.0       946          36     94603         10     R       60
# 578162      15044.0       952          12     61N22         12     R       50
# 578168      15090.0       935           3     93503         12     R       10
# 578171      15142.0       905           8     90501         11     R       60
# 578174      15017.0       946          36     94601         12     R       10
# 578177      15108.0       929          43     92902         10     R       10
# 578186      15126.0       929          43     92903         10     R       60
# 578193      15142.0       905           8     90501         11     R       10
# 578201      15057.0       946          36     94602         12     R       10
# 578207      15071.0       929          43     54C28         20     C      473
#
#         LOTAREA STYLE  STORIES  YEARBLT  EXTERIORFINISH  ROOF  TOTALROOMS  \
# 7          1440   NaN      NaN      NaN             NaN   NaN         NaN
# 9          2880   NaN      NaN      NaN             NaN   NaN         NaN
# 11         1015    13      2.0   1910.0             2.0   4.0         8.0
# 12          476    11      2.0   1910.0             2.0   4.0         2.0
# 14         6192   NaN      NaN      NaN             NaN   NaN         NaN
# 16         5279   NaN      NaN      NaN             NaN   NaN         NaN
# 49        85225   NaN      NaN      NaN             NaN   NaN         NaN
# 75        29818   NaN      NaN      NaN             NaN   NaN         NaN
# 77         6590   NaN      NaN      NaN             NaN   NaN         NaN
# 101        2599   NaN      NaN      NaN             NaN   NaN         NaN
# 104        4800   NaN      NaN      NaN             NaN   NaN         NaN
# 108        1445   NaN      NaN      NaN             NaN   NaN         NaN
# 110        4423   NaN      NaN      NaN             NaN   NaN         NaN
# 134        5600   NaN      NaN      NaN             NaN   NaN         NaN
# 137       61620   NaN      NaN      NaN             NaN   NaN         NaN
# 141        1600   NaN      NaN      NaN             NaN   NaN         NaN
# 143        7000   NaN      NaN      NaN             NaN   NaN         NaN
# 148        2940   NaN      NaN      NaN             NaN   NaN         NaN
# 151           0    21      1.0   2007.0             7.0   4.0         3.0
# 156           0    21      1.0   2007.0             7.0   4.0         3.0
# 159           0    21      1.0   2007.0             7.0   4.0         4.0
# 160           0    21      1.0   2007.0             7.0   4.0         3.0
# 166        3416   NaN      NaN      NaN             NaN   NaN         NaN
# 173        2736   NaN      NaN      NaN             NaN   NaN         NaN
# 174        1500   NaN      NaN      NaN             NaN   NaN         NaN
# ...         ...   ...      ...      ...             ...   ...         ...
# 578066    11412     4      2.0   1996.0             1.0   1.0         8.0
# 578069    12588     4      2.0   1995.0             1.0   1.0         8.0
# 578074     2962     9      2.0   2003.0             1.0   1.0         8.0
# 578081     2947     9      1.0   2001.0             1.0   1.0         6.0
# 578086     1785     9      2.0   1987.0             1.0   1.0         4.0
# 578088     9663     1      1.0   1963.0             6.0   1.0         6.0
# 578100     5918    16      1.0   1900.0             1.0   1.0         7.0
# 578109    10803     4      2.0   1994.0             1.0   1.0         8.0
# 578112     8925     9      2.0   1985.0             6.0   1.0         4.0
# 578124     1817     9      2.0   1986.0             6.0   1.0         5.0
# 578125    10138     4      2.0   1990.0             1.0   1.0         8.0
# 578136     1887     9      2.0   1978.0             6.0   1.0         7.0
# 578139    76230     1      1.0   1958.0             2.0   1.0         6.0
# 578141    26205     4      2.0   2015.0             1.0   1.0         9.0
# 578142     1595     9      2.0   1978.0             1.0   1.0         6.0
# 578153     1612     9      2.0   1985.0             1.0   1.0         4.0
# 578162        0    26      1.0   2000.0             1.0   1.0         6.0
# 578168   145534     1      1.0   1955.0             2.0   1.0         6.0
# 578171     5015     9      2.0   2004.0             2.0   1.0         7.0
# 578174    13024     4      2.0   1995.0             2.0   1.0         8.0
# 578177    13200     4      2.0   2008.0             1.0   1.0         8.0
# 578186     2493     9      2.0   1992.0             1.0   1.0         5.0
# 578193    14984     7      1.0   1996.0             2.0   1.0         9.0
# 578201     6327     4      2.0   2008.0             1.0   1.0         8.0
# 578207    12592     1      1.0   1960.0             2.0   1.0         8.0
#
#         FULLBATHS  HALFBATHS  FIREPLACES  FINISHEDLIVINGAREA
# 7             NaN        NaN         NaN                 NaN
# 9             NaN        NaN         NaN                 NaN
# 11            2.0        0.0         0.0              1122.0
# 12            1.0        0.0         0.0               544.0
# 14            NaN        NaN         NaN                 NaN
# 16            NaN        NaN         NaN                 NaN
# 49            NaN        NaN         NaN                 NaN
# 75            NaN        NaN         NaN                 NaN
# 77            NaN        NaN         NaN                 NaN
# 101           NaN        NaN         NaN                 NaN
# 104           NaN        NaN         NaN                 NaN
# 108           NaN        NaN         NaN                 NaN
# 110           NaN        NaN         NaN                 NaN
# 134           NaN        NaN         NaN                 NaN
# 137           NaN        NaN         NaN                 NaN
# 141           NaN        NaN         NaN                 NaN
# 143           NaN        NaN         NaN                 NaN
# 148           NaN        NaN         NaN                 NaN
# 151           2.0        0.0         NaN              1520.0
# 156           2.0        0.0         NaN              1324.0
# 159           2.0        0.0         NaN              1275.0
# 160           1.0        1.0         NaN               888.0
# 166           NaN        NaN         NaN                 NaN
# 173           NaN        NaN         NaN                 NaN
# 174           NaN        NaN         NaN                 NaN
# ...           ...        ...         ...                 ...
# 578066        2.0        1.0         NaN              2120.0
# 578069        2.0        1.0         0.0              2240.0
# 578074        2.0        1.0         0.0              1972.0
# 578081        2.0        0.0         0.0              1559.0
# 578086        1.0        1.0         0.0              1040.0
# 578088        1.0        1.0         0.0              1248.0
# 578100        2.0        0.0         NaN              1547.0
# 578109        2.0        1.0         1.0              2041.0
# 578112        1.0        1.0         1.0               992.0
# 578124        1.0        1.0         0.0               992.0
# 578125        1.0        1.0         1.0              2244.0
# 578136        1.0        1.0         1.0              1308.0
# 578139        1.0        1.0         1.0              1258.0
# 578141        4.0        1.0         NaN              2796.0
# 578142        1.0        1.0         1.0              1340.0
# 578153        1.0        1.0         0.0              1008.0
# 578162        2.0        1.0         0.0              1596.0
# 578168        2.0        0.0         1.0              1976.0
# 578171        2.0        1.0         1.0              1901.0
# 578174        2.0        1.0         0.0              2510.0
# 578177        2.0        1.0         NaN              2464.0
# 578186        1.0        1.0         0.0              1464.0
# 578193        2.0        2.0         2.0              3982.0
# 578201        2.0        2.0         NaN              2300.0
# 578207        2.0        0.0         0.0              1452.0
#
# [181257 rows x 32 columns]

# %% [markdown]
# Great, now we're down to 180,000 or so instances of legitimate sales on the housing market. Glancing at the differences between appraisal values and sale values, things appear to be normal.

# %% [markdown]
# ##### Graphing Qualitative Data

# %% [markdown]
# Now we can check to see which columns are easy candidates for graphing some qualitative data.
#
# The way we're doing this is great, but actually, some of the numeric values that don't show up are in fact qualitative. For instance, `STYLE` and `ROOF` are examples of two features that have numeric codes that refer to qualitative data.

# %%
ach_types = pd.DataFrame(ach_dfr.dtypes)
ach_types_r = ach_types[ach_types[0] == "O"]

# %%
ach_types_r
# Out:
#                 0
# PARID      object
# SALEDATE   object
# SALECODE   object
# SALEDESC   object
# NEIGHCODE  object
# CLASS      object
# STYLE      object

# %% [markdown]
# ###### Frequency Tables
#
# Let's check the frequency of each type of valid sale.

# %%
freq_table = pd.DataFrame(ach_dfr.loc[:, "SALECODE"].value_counts())
freq_table.columns = ["Frequency"]
freq_table
# Out:
#     Frequency
# 0      131995
# U       29846
# UR      19416

# %% [markdown]
# How about building styles?

# %%
freq_table = pd.DataFrame(ach_dfr.loc[:, "STYLE"].value_counts())
freq_table.columns = ["Frequency"]
freq_table
# Out:
#       Frequency
# 4         39255
# 16        37351
# 1         26908
# 5         15009
# 3          7615
# 9          6513
# 13         6375
# 2          4699
# 16.0       3934
# 18         2983
# 4.0        2806
# 20         2524
# 25         1622
# 12         1476
# 22         1469
# 1.0        1271
# 26         1146
# 7          1116
# 11         1072
# 21.0        934
# 13.0        884
# 24          827
# 21          752
# 5.0         718
# 22.0        606
# ...         ...
# 12.0        340
# 25.0        335
# 3.0         306
# 11.0        286
# 14          199
# 27          183
# 24.0        176
# 27.0        149
# 19.0         94
# 7.0          80
# M2           79
# M1           63
# 18.0         61
# 17           58
# 10           54
# 14.0         50
# 6            43
# 15           37
# 8            31
# 23           28
# 26.0         15
# 8.0          10
# 6.0           3
# 15.0          3
# 17.0          1
#
# [54 rows x 1 columns]

# %% [markdown]
# Let's do one more.

# %%
freq_table = pd.DataFrame(ach_dfr.loc[:, "STORIES"].value_counts())
freq_table.columns = ["Frequency"]
freq_table
# Out:
#      Frequency
# 2.0      98824
# 1.0      61713
# 1.5       9163
# 2.5       3002
# 3.0       1297
# 1.8        139
# 1.7         23
# 2.7          4
# 2.8          3
# 4.0          2

# %%
freq_table["RelativeFrequency"] = freq_table["Frequency"] / freq_table.Frequency.sum()
freq_table
# Out:
#      Frequency  RelativeFrequency
# 2.0      98824           0.567400
# 1.0      61713           0.354326
# 1.5       9163           0.052610
# 2.5       3002           0.017236
# 3.0       1297           0.007447
# 1.8        139           0.000798
# 1.7         23           0.000132
# 2.7          4           0.000023
# 2.8          3           0.000017
# 4.0          2           0.000011

# %% [markdown]
# ###### Pie Charts

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize = [12,12])
plt.pie(freq_table.RelativeFrequency)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e186e0d6d8>,
#   <matplotlib.patches.Wedge at 0x1e186e0dbe0>,
#   <matplotlib.patches.Wedge at 0x1e186e160b8>,
#   <matplotlib.patches.Wedge at 0x1e186e16588>,
#   <matplotlib.patches.Wedge at 0x1e186e16a58>,
#   <matplotlib.patches.Wedge at 0x1e186e16f28>,
#   <matplotlib.patches.Wedge at 0x1e186e20438>,
#   <matplotlib.patches.Wedge at 0x1e186e20908>,
#   <matplotlib.patches.Wedge at 0x1e186e20dd8>,
#   <matplotlib.patches.Wedge at 0x1e186e2b2e8>],
#  [Text(-0.23118001103103925, 1.0754328442537398, ''),
#   Text(-0.03757198974074907, -1.099358151644368, ''),
#   Text(1.0418761219792068, -0.3528372804134641, ''),
#   Text(1.0936965106834748, -0.11759227236001439, ''),
#   Text(1.0995193350038357, -0.032515103455516316, ''),
#   Text(1.0999926258599493, -0.0040277852144747165, ''),
#   Text(1.0999996991822374, -0.0008135102872435697, ''),
#   Text(1.0999999649223489, -0.000277796384953245, ''),
#   Text(1.0999999912294018, -0.00013890758168958744, ''),
#   Text(1.099999999283549, -3.9701291709358666e-05, '')])

# %% [markdown]
# ###### Bar Charts

# %%
plt.bar(freq_table.index, freq_table.RelativeFrequency)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# #### Graphing Quantitative Data

# %% [markdown]
# ##### Histogram

# %%
# histogram of sale prices

#not exactly great data for this example, but that's okay!
plt.hist(ach_dfr.loc[:, "STORIES"])
# Out:
# (array([6.1713e+04, 9.1630e+03, 1.6200e+02, 9.8824e+04, 0.0000e+00,
#         3.0060e+03, 1.3000e+03, 0.0000e+00, 0.0000e+00, 2.0000e+00]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <a list of 10 Patch objects>)
